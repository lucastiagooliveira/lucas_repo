# %% [markdown]
# # Looking for another place to increase the Gold's Gym

# %% [markdown]
# ## Explane the problem

# %% [markdown]
# The Gold's Gym is, maybe, the most famous gyms network in the world, where many actors and famous people use to workout. More especially, the unity located in Los Angeles (735 S Figueroa St Ste 100, Los Angeles, CA 90017, Estados Unidos), where is very crowded because it has many users using the same place at the same time. For spread and don't lose your clients, the owner had one idea: "I want to open a new gym around 500 meters the old gym!". But he knows in this neighborhood have a lot of competitors with other gyms, to decrease the change to lose clients the owner wants to know how he can open the new gym station in a location with fewer concurrents.
#
# That information is really important for the owner of the gold's gym because he can improve the high investment, he'd use to expand the gym.

# %% [markdown]
# ## What's the dataset we need to solve this problem?

# %% [markdown]
# To solve this problem, we need to get through the Foursquare API the location of another gym around the Gold's Gym and for cluster those gyms we'll use the K-Means algorithm.
#
# To determine the cardinal point is better to implant a new gym, we'll use the initial point to K-Means algorithm, which in that turn tends to return the cluster with the other gyms surrounding the Gold's Gym. The region with less concurrence could be the best place to create a new establishment.
#
# For example, with the new gym has been opened in a place surrounded by other gyms, investors would lose their money with this business.

# %% [markdown]
# ## Example of the data would be use for solve this problem

# %% [markdown]
# ### Importing Library

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

import folium # plotting library

from sklearn.cluster import KMeans #KMeans library
from sklearn.preprocessing import scale

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# %% [markdown]
# ### Importing the Foursquare API

# %%
CLIENT_ID = '3JTWJGZF0FAEOFU2K5US1I4O1QG3U2YLRANJHSL33PW4RCPS' # your Foursquare ID
CLIENT_SECRET = '1LIVDOD2UKLHWHVYREMVJ1TBYAIFXYX1DNVZFCCKF3TY25G4' # your Foursquare Secret
VERSION = '20180604' # version of foursquare api
LIMIT = 500 #limit of output

# %%
# Latitude and longitude of Gold's Gym
latitude = '34.048660'
longitude = '	-118.260450'
# Query for input on foursquare
search_query = 'Gym'
#Radius of search on map
radius =800
# URL 
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=3JTWJGZF0FAEOFU2K5US1I4O1QG3U2YLRANJHSL33PW4RCPS&client_secret=1LIVDOD2UKLHWHVYREMVJ1TBYAIFXYX1DNVZFCCKF3TY25G4&ll=34.048660,\t-118.260450&v=20180604&query=Gym&radius=800&limit=500'

# %%
results = requests.get(url).json() #Json generated in foursquare api
results
# Out:
# {'meta': {'code': 200, 'requestId': '5efe1833587699312d468f73'},
#  'response': {'venues': [{'id': '4b12d08ef964a520a78e23e3',
#     'name': "Gold's Gym",
#     'location': {'address': '735 S Figueroa St Ste 100',
#      'crossStreet': 'at 7th St.',
#      'lat': 34.04866,
#      'lng': -118.26045,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.04866,
#        'lng': -118.26045}],
#      'distance': 0,
#      'postalCode': '90017',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['735 S Figueroa St Ste 100 (at 7th St.)',
#       'Los Angeles, CA 90017',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '554208029'},
#     'referralId': 'v-1593710594',
#     'hasPerk': False},
#    {'id': '4c12716877cea593810bcd60',
#     'name': 'The Gym at The Standard, Downtown LA',
#     'location': {'address': '550 S Flower St',
#      'crossStreet': '6th Street',
#      'lat': 34.0501594543457,
#      'lng': -118.25697326660156,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.0501594543457,
#        'lng': -118.25697326660156}],
#      'distance': 361,
#      'postalCode': '90071',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['550 S Flower St (6th Street)',
#       'Los Angeles, CA 90071',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593710594',
#     'hasPerk': False},
#    {'id': '4ca3b9661ee76dcb4ba8fbdd',
#     'name': '1100 Wilshire Gym',
#     'location': {'address': '1100 Wilshire Blvd',
#      'crossStreet': 'Bixel',
#      'lat': 34.05242144083761,
#      'lng': -118.26367447544168,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.05242144083761,
#        'lng': -118.26367447544168}],
#      'distance': 513,
#      'postalCode': '90017',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1100 Wilshire Blvd (Bixel)',
#       'Los Angeles, CA 90017',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593710594',
#     'hasPerk': False},
#    {'id': '4c6ebc6910faa1431899f168',
#     'name': 'Pegasus Rooftop Gym',
#     'location': {'address': '612 S Flower St',
#      'crossStreet': 'btw 6th & Wilshire',
#      'lat': 34.049878908034856,
#      'lng': -118.25721052605807,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.049878908034856,
#        'lng': -118.25721052605807}],
#      'distance': 328,
#      'postalCode': '90017',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['612 S Flower St (btw 6th & Wilshire)',
#       'Los Angeles, CA 90017',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593710594',
#     'hasPerk': False},
#    {'id': '4bcf67bf046076b0023e6e71',
#     'name': 'Piero Gym',
#     'location': {'address': '616 St Paul Ave',
#      'crossStreet': 'at Wilshire Blvd',
#      'lat': 34.052730560302734,
#      'lng': -118.26089477539062,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.052730560302734,
#        'lng': -118.26089477539062}],
#      'distance': 454,
#      'postalCode': '90017',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['616 St Paul Ave (at Wilshire Blvd)',
#       'Los Angeles, CA 90017',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593710594',
#     'hasPerk': False},
#    {'id': '4d55f1e258856dcbd7f2506d',
#     'name': '717 8th Floor Gym',
#     'location': {'address': '717 W Olympic Blvd',
#      'crossStreet': 'Figueroa',
#      'lat': 34.04508972167969,
#      'lng': -118.26332092285156,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.04508972167969,
#        'lng': -118.26332092285156}],
#      'distance': 477,
#      'postalCode': '90015',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['717 W Olympic Blvd (Figueroa)',
#       'Los Angeles, CA 90015',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593710594',
#     'hasPerk': False},
#    {'id': '4c2b3d8557a9c9b62188f567',
#     'name': 'Gym @ Eastern Columbia Bldg',
#     'location': {'address': '849 S Broadway',
#      'lat': 34.04277038574219,
#      'lng': -118.25623321533203,
#      'labeledLatLngs': [{'label': 'entrance',
#        'lat': 34.04267,
#        'lng': -118.255932},
#       {'label': 'display',
#        'lat': 34.04277038574219,
#        'lng': -118.25623321533203}],
#      'distance': 762,
#      'postalCode': '90014',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['849 S Broadway',
#       'Los Angeles, CA 90014',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593710594',
#     'hasPerk': False},
#    {'id': '4bc3c58babf49521b34dc493',
#     'name': 'SB Grand Lofts Gym',
#     'location': {'address': '312 W 5th St',
#      'crossStreet': 'at S Broadway',
#      'lat': 34.048038482666016,
#      'lng': -118.25125885009766,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.048038482666016,
#        'lng': -118.25125885009766}],
#      'distance': 850,
#      'postalCode': '90013',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['312 W 5th St (at S Broadway)',
#       'Los Angeles, CA 90013',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593710594',
#     'hasPerk': False},
#    {'id': '55c37802498e9915809ada46',
#     'name': '8th + Hope Gym',
#     'location': {'lat': 34.04635313721103,
#      'lng': -118.25973201771583,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.04635313721103,
#        'lng': -118.25973201771583}],
#      'distance': 265,
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['Los Angeles, CA', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593710594',
#     'hasPerk': False},
#    {'id': '5296245811d28a5d343fa0b3',
#     'name': 'La Urban Gym',
#     'location': {'lat': 34.04728420127556,
#      'lng': -118.26042533143553,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.04728420127556,
#        'lng': -118.26042533143553}],
#      'distance': 153,
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['Los Angeles, CA', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593710594',
#     'hasPerk': False},
#    {'id': '56772434498e8c399c823bda',
#     'name': 'sheridan gym',
#     'location': {'lat': 34.048033,
#      'lng': -118.258837,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.048033,
#        'lng': -118.258837}],
#      'distance': 164,
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['Los Angeles, CA', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593710594',
#     'hasPerk': False},
#    {'id': '50ef497b19a997994d5793bb',
#     'name': 'Gym At 655 Hope',
#     'location': {'address': '655 S Hope St',
#      'crossStreet': '7th St.',
#      'lat': 34.048370361328125,
#      'lng': -118.2576904296875,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.048370361328125,
#        'lng': -118.2576904296875}],
#      'distance': 256,
#      'postalCode': '90017',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['655 S Hope St (7th St.)',
#       'Los Angeles, CA 90017',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593710594',
#     'hasPerk': False},
#    {'id': '4c0e68392466a593aaf77821',
#     'name': 'Roosevelt Gym',
#     'location': {'address': '727 W 7th St Fl 4',
#      'crossStreet': 'Flower',
#      'lat': 34.04891038962412,
#      'lng': -118.2583875033616,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.04891038962412,
#        'lng': -118.2583875033616}],
#      'distance': 192,
#      'postalCode': '90017',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['727 W 7th St Fl 4 (Flower)',
#       'Los Angeles, CA 90017',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593710594',
#     'hasPerk': False},
#    {'id': '5cfe73095455b2002ca01a40',
#     'name': '8th & Grand Gym',
#     'location': {'lat': 34.046565,
#      'lng': -118.255859,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.046565,
#        'lng': -118.255859}],
#      'distance': 483,
#      'postalCode': '90014',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['Los Angeles, CA 90014', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593710594',
#     'hasPerk': False},
#    {'id': '4cf7e3219d11b1f7ec73c8ed',
#     'name': 'TENTEN Rooftop Gym',
#     'location': {'address': '1010 Wilshire Blvd',
#      'lat': 34.05141870255312,
#      'lng': -118.26193278596733,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.05141870255312,
#        'lng': -118.26193278596733}],
#      'distance': 336,
#      'postalCode': '90017',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1010 Wilshire Blvd',
#       'Los Angeles, CA 90017',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593710594',
#     'hasPerk': False},
#    {'id': '4e13394d8877ac23b6709240',
#     'name': 'Gym @ Luma',
#     'location': {'lat': 34.041771,
#      'lng': -118.263424,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.041771,
#        'lng': -118.263424}],
#      'distance': 814,
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['Los Angeles, CA', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593710594',
#     'hasPerk': False},
#    {'id': '4fcc22aae4b01f05189d3f62',
#     'name': 'Market Lofts Gym',
#     'location': {'address': '645 W 9th St',
#      'lat': 34.04612560177077,
#      'lng': -118.26076222583642,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.04612560177077,
#        'lng': -118.26076222583642}],
#      'distance': 283,
#      'postalCode': '90015',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['645 W 9th St',
#       'Los Angeles, CA 90015',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593710594',
#     'hasPerk': False},
#    {'id': '4ca3b459d5a2a143f4984b90',
#     'name': 'Glo Wilshire Gym',
#     'location': {'address': '1050 Wilshire Blvd',
#      'crossStreet': 'Bixel',
#      'lat': 34.05139271024456,
#      'lng': -118.26317294553697,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.05139271024456,
#        'lng': -118.26317294553697}],
#      'distance': 394,
#      'postalCode': '90017',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1050 Wilshire Blvd (Bixel)',
#       'Los Angeles, CA 90017',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593710594',
#     'hasPerk': False},
#    {'id': '4dcef4e052b1f8915ba49bc2',
#     'name': '5-two-1 Gym',
#     'location': {'address': '722 S Bixel St',
#      'crossStreet': '7th',
#      'lat': 34.050132751464844,
#      'lng': -118.2640609741211,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.050132751464844,
#        'lng': -118.2640609741211}],
#      'distance': 371,
#      'postalCode': '90017',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['722 S Bixel St (7th)',
#       'Los Angeles, CA 90017',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593710594',
#     'hasPerk': False},
#    {'id': '4fc2462be4b0f6b4ee40d4aa',
#     'name': 'FIDM Outside Gym',
#     'location': {'lat': 34.04487,
#      'lng': -118.260407,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.04487,
#        'lng': -118.260407}],
#      'distance': 421,
#      'postalCode': '90015',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['Los Angeles, CA 90015', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e7941735',
#       'name': 'Playground',
#       'pluralName': 'Playgrounds',
#       'shortName': 'Playground',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/playground_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593710594',
#     'hasPerk': False},
#    {'id': '4d2bdbe56e27a1435fe33b24',
#     'name': 'Educo Gym Parking Space',
#     'location': {'lat': 34.049316,
#      'lng': -118.255865,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.049316,
#        'lng': -118.255865}],
#      'distance': 429,
#      'cc': 'US',
#      'state': 'California',
#      'country': 'United States',
#      'formattedAddress': ['California', 'United States']},
#     'categories': [],
#     'referralId': 'v-1593710594',
#     'hasPerk': False},
#    {'id': '512afb4fe4b00ea5a28f5d49',
#     'name': 'Skyline Gym',
#     'location': {'lat': 34.0449323187996,
#      'lng': -118.26110482963111,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.0449323187996,
#        'lng': -118.26110482963111}],
#      'distance': 419,
#      'postalCode': '90015',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['Los Angeles, CA 90015', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593710594',
#     'hasPerk': False},
#    {'id': '51bc06aa498e71fc1012c9a3',
#     'name': 'The Gym @ The Chapman Flats',
#     'location': {'address': '757 S Broadway',
#      'crossStreet': '8th',
#      'lat': 34.044078999999996,
#      'lng': -118.25483700000001,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.044078999999996,
#        'lng': -118.25483700000001},
#       {'label': 'entrance', 'lat': 34.044025, 'lng': -118.254648}],
#      'distance': 726,
#      'postalCode': '90014',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['757 S Broadway (8th)',
#       'Los Angeles, CA 90014',
#       'United States']},
#     'categories': [{'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'shortName': 'Residential',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593710594',
#     'hasPerk': False},
#    {'id': '4c121f6a7f7f2d7fd1a5dc68',
#     'name': 'Gym @The Chapman (flats)',
#     'location': {'address': '8th & Broadway',
#      'lat': 34.043595,
#      'lng': -118.254381,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.043595,
#        'lng': -118.254381}],
#      'distance': 794,
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['8th & Broadway',
#       'Los Angeles, CA',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593710594',
#     'hasPerk': False},
#    {'id': '4e15e2b918384368edd3f4e8',
#     'name': 'Packard Gym',
#     'location': {'address': '1000 S Hope St',
#      'lat': 34.04311200072276,
#      'lng': -118.26163172721863,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.04311200072276,
#        'lng': -118.26163172721863},
#       {'label': 'entrance', 'lat': 34.04348, 'lng': -118.261592}],
#      'distance': 627,
#      'postalCode': '90015',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1000 S Hope St',
#       'Los Angeles, CA 90015',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593710594',
#     'hasPerk': False},
#    {'id': '52cc32f011d261a2a31e4809',
#     'name': 'Ace Hotel Gym',
#     'location': {'address': '929 S Broadway',
#      'lat': 34.041872,
#      'lng': -118.25699499999999,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.041872,
#        'lng': -118.25699499999999},
#       {'label': 'entrance', 'lat': 34.041714, 'lng': -118.256833}],
#      'distance': 820,
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['929 S Broadway',
#       'Los Angeles, CA',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593710594',
#     'hasPerk': False},
#    {'id': '4da505f40cb635c4a586f6e2',
#     'name': 'Premiere Gym',
#     'location': {'lat': 34.046482,
#      'lng': -118.254246,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.046482,
#        'lng': -118.254246}],
#      'distance': 621,
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['Los Angeles, CA', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593710594',
#     'hasPerk': False},
#    {'id': '4c9f5b3619e4236a4efa5789',
#     'name': 'Millenium Biltmore Gym',
#     'location': {'lat': 34.04890858282236,
#      'lng': -118.25333897510248,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.04890858282236,
#        'lng': -118.25333897510248}],
#      'distance': 656,
#      'postalCode': '90014',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['Los Angeles, CA 90014', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593710594',
#     'hasPerk': False},
#    {'id': '52c9c7d3498e933c2e07ede5',
#     'name': 'Union Lofts Gym',
#     'location': {'lat': 34.044459,
#      'lng': -118.255349,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.044459,
#        'lng': -118.255349}],
#      'distance': 663,
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['Los Angeles, CA', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593710594',
#     'hasPerk': False},
#    {'id': '4bf179e2408ec92824f26600',
#     'name': 'Met Lofts Gym',
#     'location': {'address': '1050 S Flower St',
#      'crossStreet': 'at W. 11th St',
#      'lat': 34.043155230105825,
#      'lng': -118.26337537812593,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.043155230105825,
#        'lng': -118.26337537812593}],
#      'distance': 669,
#      'postalCode': '90015',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1050 S Flower St (at W. 11th St)',
#       'Los Angeles, CA 90015',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593710594',
#     'hasPerk': False},
#    {'id': '4bb8ef557421a5938a4ac240',
#     'name': 'Great Republic Lofts Gym',
#     'location': {'address': '756 S Spring St',
#      'crossStreet': 'at 8th St',
#      'lat': 34.042816163180916,
#      'lng': -118.25339514721523,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.042816163180916,
#        'lng': -118.25339514721523}],
#      'distance': 920,
#      'postalCode': '90014',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['756 S Spring St (at 8th St)',
#       'Los Angeles, CA 90014',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593710594',
#     'hasPerk': False},
#    {'id': '4d5bf0f99ac9a093e11e6b94',
#     'name': 'Good Samaritan Hospital Employee Gym',
#     'location': {'lat': 34.052149,
#      'lng': -118.268241,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.052149,
#        'lng': -118.268241}],
#      'distance': 816,
#      'postalCode': '90017',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['Los Angeles, CA 90017', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593710594',
#     'hasPerk': False},
#    {'id': '51a59071498e284d0cf3215e',
#     'name': 'TU Gym',
#     'location': {'lat': 34.052973,
#      'lng': -118.266105,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.052973,
#        'lng': -118.266105}],
#      'distance': 708,
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['Los Angeles, CA', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593710594',
#     'hasPerk': False},
#    {'id': '4f651bcee4b0788a8feca2fc',
#     'name': 'Los Angeles Marriot Downtown Gym',
#     'location': {'lat': 34.05483980593216,
#      'lng': -118.25618839943402,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.05483980593216,
#        'lng': -118.25618839943402}],
#      'distance': 792,
#      'cc': 'US',
#      'state': 'California',
#      'country': 'United States',
#      'formattedAddress': ['California', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593710594',
#     'hasPerk': False},
#    {'id': '551c3384498ea9fdf6768a34',
#     'name': 'Los Angeles Hard Gym',
#     'location': {'lat': 34.042519,
#      'lng': -118.255992,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.042519,
#        'lng': -118.255992}],
#      'distance': 797,
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['Los Angeles, CA', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593710594',
#     'hasPerk': False},
#    {'id': '59d414f450a6f07a612ab6c3',
#     'name': 'Sofia-Equinox Gym',
#     'location': {'address': '1120 W 6th St',
#      'lat': 34.05410158551778,
#      'lng': -118.26299974249567,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.05410158551778,
#        'lng': -118.26299974249567}],
#      'distance': 649,
#      'postalCode': '90017',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1120 W 6th St',
#       'Los Angeles, CA 90017',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593710594',
#     'hasPerk': False},
#    {'id': '4f891393e4b0298189e82b5e',
#     'name': 'Gym inside omni hotel',
#     'location': {'lat': 34.052725495241816,
#      'lng': -118.25042097838254,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.052725495241816,
#        'lng': -118.25042097838254}],
#      'distance': 1029,
#      'postalCode': '90012',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['Los Angeles, CA 90012', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593710594',
#     'hasPerk': False},
#    {'id': '4fbd9771e4b06ff81454693b',
#     'name': 'K-gym',
#     'location': {'lat': 34.04901076273991,
#      'lng': -118.25179718264066,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.04901076273991,
#        'lng': -118.25179718264066}],
#      'distance': 799,
#      'postalCode': '90013',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['Los Angeles, CA 90013', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593710594',
#     'hasPerk': False},
#    {'id': '4e6985cbe4cdb375512ee1c9',
#     'name': 'TGB Gym',
#     'location': {'lat': 34.049442424039285,
#      'lng': -118.25170010635436,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.049442424039285,
#        'lng': -118.25170010635436}],
#      'distance': 811,
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['Los Angeles, CA', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593710594',
#     'hasPerk': False},
#    {'id': '509bfed5e4b005c81a227fe7',
#     'name': 'SB Lofts - Gym',
#     'location': {'address': '548 S Spring St Bsmt',
#      'crossStreet': '6th St.',
#      'lat': 34.0462316789065,
#      'lng': -118.25048950333756,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.0462316789065,
#        'lng': -118.25048950333756}],
#      'distance': 957,
#      'postalCode': '90013',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['548 S Spring St Bsmt (6th St.)',
#       'Los Angeles, CA 90013',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593710594',
#     'hasPerk': False},
#    {'id': '512c2d49e4b0ac0dea5729a5',
#     'name': 'Blackstone Gym',
#     'location': {'address': '901 S Broadway',
#      'lat': 34.042354583740234,
#      'lng': -118.25653839111328,
#      'labeledLatLngs': [{'label': 'entrance',
#        'lat': 34.042289,
#        'lng': -118.256278},
#       {'label': 'display',
#        'lat': 34.042354583740234,
#        'lng': -118.25653839111328}],
#      'distance': 789,
#      'postalCode': '90015',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['901 S Broadway',
#       'Los Angeles, CA 90015',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593710594',
#     'hasPerk': False},
#    {'id': '4b061e2cf964a520d5e822e3',
#     'name': "CheChi's Gym",
#     'location': {'address': '621 S Spring St',
#      'lat': 34.04554748535156,
#      'lng': -118.2518539428711,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.04554748535156,
#        'lng': -118.2518539428711}],
#      'distance': 865,
#      'postalCode': '90014',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['621 S Spring St',
#       'Los Angeles, CA 90014',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593710594',
#     'hasPerk': False},
#    {'id': '50e43fe2e4b0f6f2e676fc20',
#     'name': 'Metropolitan Gym',
#     'location': {'address': '315 W 5th St',
#      'lat': 34.048479,
#      'lng': -118.250841,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.048479,
#        'lng': -118.250841}],
#      'distance': 886,
#      'postalCode': '90013',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['315 W 5th St',
#       'Los Angeles, CA 90013',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593710594',
#     'hasPerk': False},
#    {'id': '59af76e2ca18ea7be8554d05',
#     'name': '7 West DTLA GYM',
#     'location': {'lat': 34.052952,
#      'lng': -118.268665,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.052952,
#        'lng': -118.268665}],
#      'distance': 895,
#      'postalCode': '90017',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['Los Angeles, CA 90017', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593710594',
#     'hasPerk': False},
#    {'id': '4dd40e7c45dd98b61e7b00e2',
#     'name': 'The Judson Gym',
#     'location': {'lat': 34.048943903313635,
#      'lng': -118.25002695935918,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.048943903313635,
#        'lng': -118.25002695935918}],
#      'distance': 961,
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['Los Angeles, CA', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593710594',
#     'hasPerk': False},
#    {'id': '4df7b8ddb0fbaeaaabe5dc17',
#     'name': 'The Global  Gym',
#     'location': {'lat': 34.05303216,
#      'lng': -118.25028643,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.05303216,
#        'lng': -118.25028643}],
#      'distance': 1056,
#      'postalCode': '90071',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['Los Angeles, CA 90071', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593710594',
#     'hasPerk': False},
#    {'id': '4bce5d1968f976b0ec086683',
#     'name': 'Bixel at Fifth - Gym and Rec Room',
#     'location': {'address': '1311 W 5th St',
#      'crossStreet': 'Bixel St',
#      'lat': 34.05696700289535,
#      'lng': -118.26182165445354,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.05696700289535,
#        'lng': -118.26182165445354}],
#      'distance': 933,
#      'postalCode': '90017',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1311 W 5th St (Bixel St)',
#       'Los Angeles, CA 90017',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593710594',
#     'hasPerk': False},
#    {'id': '4a62ae6cf964a52072c41fe3',
#     'name': 'The Westin Bonaventure Hotel & Suites, Los Angeles',
#     'location': {'address': '404 S Figueroa St',
#      'crossStreet': 'btwn 4th & 5th St',
#      'lat': 34.0527773,
#      'lng': -118.255596,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.0527773,
#        'lng': -118.255596}],
#      'distance': 640,
#      'postalCode': '90071',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['404 S Figueroa St (btwn 4th & 5th St)',
#       'Los Angeles, CA 90071',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593710594',
#     'hasPerk': False},
#    {'id': '59bae98b0d173f3bdf8a0771',
#     'name': 'Hotel Indigo Pool',
#     'location': {'address': '899 Francisco St',
#      'lat': 34.047884,
#      'lng': -118.26385900000001,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.047884,
#        'lng': -118.26385900000001}],
#      'distance': 326,
#      'postalCode': '90017',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['899 Francisco St',
#       'Los Angeles, CA 90017',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d132951735',
#       'name': 'Hotel Pool',
#       'pluralName': 'Hotel Pools',
#       'shortName': 'Pool',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593710594',
#     'hasPerk': False},
#    {'id': '4cc91668d063a143f7b40bb4',
#     'name': 'WestinWORKOUT',
#     'location': {'address': 'Westin Bonaventure',
#      'crossStreet': 'Green Tower, 3rd Floor',
#      'lat': 34.05307512367909,
#      'lng': -118.25614048318694,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.05307512367909,
#        'lng': -118.25614048318694}],
#      'distance': 632,
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['Westin Bonaventure (Green Tower, 3rd Floor)',
#       'Los Angeles, CA',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593710594',
#     'hasPerk': False}]}}

# %% [markdown]
# ### Data mining

# %%
# assign relevant part of JSON to venues
gyms = results['response']['venues']

# tranform json into a dataframe
df = json_normalize(gyms)
# drop the first row, because this is the Gold's Gym location
df = df.drop(0, axis = 0)
#reset index the in
df.reset_index(drop = True, inplace = True)
# show the shape of the dataframe 
df.shape
# Out:
# C:\Users\lucas\anaconda3\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
# (49, 18)

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in df.columns if col.startswith('location.')] + ['id']
dataframe_filtered = df.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered.shape
# Out:
# (49, 15)

# %% [markdown]
# ### Printing the Map

# %%
gym_map = folium.Map(location=[latitude, longitude], zoom_start=15) # generate map centred around the Gold's Gym

# add a red circle marker to represent the Gold's Gym
folium.Marker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup="Gold's Gym",
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
    ).add_to(gym_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.name):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(gym_map)

# display map
gym_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Clustering the locations

# %%
# filtring dataframe for best localization in map
x = dataframe_filtered[['lat', 'lng']]
# seting the start point for KMeans methods, because this represents cardinal points
start_point = np.array([[34.06079,-118.264444],[34.031588,-118.260010],[34.049686,-118.284829],[34.048864,-118.237971]])

# %%
# scaling the data
data = scale(x)
# start_point = scale(start_point)
neigh = KMeans(n_clusters = 4, init = start_point, max_iter = 500)
#fit the model
neigh.fit(x)
# Out:
# C:\Users\lucas\anaconda3\lib\site-packages\ipykernel_launcher.py:6: RuntimeWarning: Explicit initial center position passed: performing only one init in k-means instead of n_init=10
# KMeans(algorithm='auto', copy_x=True,
#        init=array([[  34.06079 , -118.264444],
#        [  34.031588, -118.26001 ],
#        [  34.049686, -118.284829],
#        [  34.048864, -118.237971]]),
#        max_iter=500, n_clusters=4, n_init=10, n_jobs=None,
#        precompute_distances='auto', random_state=None, tol=0.0001, verbose=0)

# %%
# insert the cluster labels into data frame
dataframe_filtered.insert(0, 'Cluster Labels', neigh.labels_)

# %%
# print the head of dataframe
dataframe_filtered.head()
# Out:
#    Cluster Labels                                  name categories  \
# 0               3  The Gym at The Standard, Downtown LA        Gym
# 1               0                     1100 Wilshire Gym        Gym
# 2               3                   Pegasus Rooftop Gym        Gym
# 3               0                             Piero Gym        Gym
# 4               1                     717 8th Floor Gym        Gym
#
#               address         crossStreet        lat         lng  \
# 0     550 S Flower St          6th Street  34.050159 -118.256973
# 1  1100 Wilshire Blvd               Bixel  34.052421 -118.263674
# 2     612 S Flower St  btw 6th & Wilshire  34.049879 -118.257211
# 3     616 St Paul Ave    at Wilshire Blvd  34.052731 -118.260895
# 4  717 W Olympic Blvd            Figueroa  34.045090 -118.263321
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 0  [{'label': 'display', 'lat': 34.0501594543457,...       361      90071  US
# 1  [{'label': 'display', 'lat': 34.05242144083761...       513      90017  US
# 2  [{'label': 'display', 'lat': 34.04987890803485...       328      90017  US
# 3  [{'label': 'display', 'lat': 34.05273056030273...       454      90017  US
# 4  [{'label': 'display', 'lat': 34.04508972167969...       477      90015  US
#
#           city state        country  \
# 0  Los Angeles    CA  United States
# 1  Los Angeles    CA  United States
# 2  Los Angeles    CA  United States
# 3  Los Angeles    CA  United States
# 4  Los Angeles    CA  United States
#
#                                     formattedAddress                        id
# 0  [550 S Flower St (6th Street), Los Angeles, CA...  4c12716877cea593810bcd60
# 1  [1100 Wilshire Blvd (Bixel), Los Angeles, CA 9...  4ca3b9661ee76dcb4ba8fbdd
# 2  [612 S Flower St (btw 6th & Wilshire), Los Ang...  4c6ebc6910faa1431899f168
# 3  [616 St Paul Ave (at Wilshire Blvd), Los Angel...  4bcf67bf046076b0023e6e71
# 4  [717 W Olympic Blvd (Figueroa), Los Angeles, C...  4d55f1e258856dcbd7f2506d

# %% [markdown]
# ### Printing the map with clusters

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=15)

# set color scheme for the clusters
x = np.arange(4)
ys = [i + x + (i*x)**2 for i in range(4)]
colors_array = ['green','red','darkblue','black']
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(dataframe_filtered['lat'], dataframe_filtered['lng'], dataframe_filtered['name'], dataframe_filtered['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
# add the gold's gym's marks   
folium.Marker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup="Gold's Gym",
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
    ).add_to(map_clusters)
# print the map      
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Quantity of gyms in each clusters

# %%
#selecting relevants values
result = dataframe_filtered[['Cluster Labels', 'name']]

# %%
#showing the quantity of gym in each cluster
result_group = result.groupby(by = 'Cluster Labels', axis = 0).count()
# change index
result_group.reset_index(inplace = True)
# change colums name
result_group.columns = ['Cluster Labels', 'Number of gyms']

# %%
#replace the clusters numbers
for i, j in enumerate(result_group['Cluster Labels']):
    if j == 0:
        result_group['Cluster Labels'][i] = 'West'
    elif j == 1:
        result_group['Cluster Labels'][i] = 'South'
    elif j == 2:
        result_group['Cluster Labels'][i] = 'East'
    elif j == 3:
        result_group['Cluster Labels'][i] = 'North'
# Out:
# C:\Users\lucas\anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\lucas\anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\lucas\anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
result_group
# Out:
#   Cluster Labels  Number of gyms
# 0           West              10
# 1          South              13
# 2           East              11
# 3          North              15

# %%
# ------- PART 1: Define a function that do a plot for one line of the dataset!
 
def make_spider(title, color):
 
    #number of variable
    categories=list(result_group['Cluster Labels'])
    categories.reverse()
    N = len(categories)

    # What will be the angle of each axis in the plot? (we divide the plot / number of variable)
    angles = [(n / float(N) * 2 * pi) for n in range(N)]
#    angles.reverse()
    angles += angles[:1]


    # Initialise the spider plot
    ax = plt.subplot(111, polar=True)

    # If you want the first axis to be on top:
    ax.set_theta_offset(pi / 2)
    ax.set_theta_direction(-1)

    # Draw one axe per variable + add labels labels yet
    plt.xticks(angles[:-1], categories, color='grey', size= 12, fontweight = 'bold')

    # Draw ylabels
    ax.set_rlabel_position(0)
    plt.yticks([5,10,15], ["5","10","15"], color="grey", size=13, verticalalignment = 'top', y = 0.8)
    plt.ylim(0,17)

    # Ind1
    values=result_group['Number of gyms'].tolist()
    values.reverse()
    values += values[:1]
    
    ax.plot(angles, values, color= color, linewidth=5, linestyle='solid')
    ax.fill(angles, values, color=color , alpha=0.5)

#     # Add a title
#     plt.title(title, size=30, color=color, y=1.1)

#Part 2 Apply to all individuals
# initialize the figure
my_dpi=96
plt.figure(figsize=(800/my_dpi, 800/my_dpi), dpi=my_dpi)
 
# Create a color palette:
my_palette = plt.cm.get_cmap("Set3", 10)

make_spider(title= 'Gyms around', color = my_palette(2))
plt.savefig('radar.png', transparent= True)
