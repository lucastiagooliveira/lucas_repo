# %% [markdown]
# # First test

# %%
from utils import *
from fastai.vision.data import *
import pandas as pd

# %%
df_train = pd.read_csv('https://raw.githubusercontent.com/lucastiagooliveira/lucas_repo/master/Kaggle/digit-recognizer/train.csv')
df_test = pd.read_csv('https://raw.githubusercontent.com/lucastiagooliveira/lucas_repo/master/Kaggle/digit-recognizer/test.csv')

# %%
train = ImageDataLoaders.from_csv("C:/Users/lucas/Documents/lucastiagooliveira/Kaggle/digit-recognizer", csv_fname='train.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-26-b7b91cd6101b> in <module>
# ----> 1 train = ImageDataLoaders.from_csv("C:/Users/lucas/Documents/lucastiagooliveira/Kaggle/digit-recognizer", csv_fname='train.csv')
#
# c:\users\lucas\anaconda3\lib\site-packages\fastai\vision\data.py in from_csv(cls, path, csv_fname, header, delimiter, **kwargs)
#     144         "Create from `path/csv_fname` using `fn_col` and `label_col`"
#     145         df = pd.read_csv(Path(path)/csv_fname, header=header, delimiter=delimiter)
# --> 146         return cls.from_df(df, path=path, **kwargs)
#     147
#     148     @classmethod
#
# c:\users\lucas\anaconda3\lib\site-packages\fastai\vision\data.py in from_df(cls, df, path, valid_pct, seed, fn_col, folder, suff, label_col, label_delim, y_block, valid_col, item_tfms, batch_tfms, **kwargs)
# ...
