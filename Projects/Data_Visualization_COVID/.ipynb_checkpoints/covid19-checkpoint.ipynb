# %% [markdown]
# # Visualização dos dados do COVID-19 no Brasil.
# >
#
# - toc: false
# - badges: true
# - comments: true
# - categories: [visualiação, covid19]
# - image:

# %%
import pandas as pd
import altair as alt

# %%
df = pd.read_excel('https://github.com/lucastiagooliveira/lucas_repo/blob/master/dados/covid/covid19.xlsx?raw=true')

# %%
df.tail()
# Out:
#               regiao estado municipio  coduf    codmun  codRegiaoSaude  \
# 909521  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 909522  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 909523  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 909524  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 909525  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
#
#          nomeRegiaoSaude       data  semanaEpi  populacaoTCU2019  \
# 909521  DISTRITO FEDERAL 2020-08-31         36         3015268.0
# 909522  DISTRITO FEDERAL 2020-09-01         36         3015268.0
# 909523  DISTRITO FEDERAL 2020-09-02         36         3015268.0
# 909524  DISTRITO FEDERAL 2020-09-03         36         3015268.0
# 909525  DISTRITO FEDERAL 2020-09-04         36         3015268.0
#
#         casosAcumulado  casosNovos  obitosAcumulado  obitosNovos  \
# 909521          162042        1246             2521           52
# ...

# %%
label = alt.selection_single(
    encodings=['x'], # limit selection to x-axis value
    on='mouseover',  # select on mouseover events
    nearest=True,    # select data point nearest the cursor
    empty='none'     # empty selection includes no data points
)

base = alt.Chart(df.loc[df.municipio == 'Uberlândia']).mark_line().encode(
    alt.X('data:T'),
    alt.Y('casosAcumulado:Q'),
    color='category:N'
)

base1 = alt.Chart(df.loc[df.municipio == 'Brasília']).mark_line().encode(
    alt.X('data:T'),
    alt.Y('casosAcumulado:Q'),
    color='category:N'
)

alt.layer(
    base,
    
    base1,
    
    alt.Chart().mark_rule(color='#aaa').encode(
        x='data:T'
        ).transform_filter(label),
    
    base.mark_circle().encode(
        opacity=alt.condition(label, alt.value(1), alt.value(0))
        ).add_selection(label),
    
    base.mark_text(align='right', dx=-15, dy=15, stroke='white', strokeWidth=5).encode(
        text='casosAcumulado:Q'
        ).transform_filter(label),
    
    base.mark_text(align='right', dx=-15, dy=0).encode(
        text='casosAcumulado:Q'
    ).transform_filter(label),
    
    base.mark_text(align='right', dx=-15, dy=15).encode(
        text='data:T'
    ).transform_filter(label),
    
).properties(
    width=600,
    height=400
)
# Out:
# alt.LayerChart(...)
